# %% [markdown]
# <a href="https://colab.research.google.com/github/Tirta2241720045/PCVK_Ganjil_2024/blob/main/Week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow  # for image display
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %%
# Membuat list untuk menyimpan url dari beberapa image
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
        "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
        "https://th.bing.com/th/id/OIP.eIJ1__zkGFIsa_waGicIVQAAAA?w=449&h=449&rs=1&pid=ImgDetMain"]

# baca dan tampilkan image
# loop pada tiap url image, beberapa image dapat disimpan pada list
for url in urls:
    image = io.imread(url)                           # read image
    image = cv.resize(image, (0,0), fx=0.5, fy=0.5)  # resize image to half size
    image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)   # convert color to RGB
    final_frame = cv.hconcat([image, image_2])       # concatenate image
    cv2_imshow(final_frame)                          # show image
    print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=448x224>

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("resolusi image: tinggi x lebar = ", tinggi, " x ",lebar)
cv2_imshow(image_2)
# Out:
# resolusi image: tinggi x lebar =  224  x  224
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#Membuat garis horizontal ditengah image
for y in range (lebar):
    image_3[int((tinggi)/2), y] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=448x224>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# Membuat garis vertikal di tengah gambar
for x in range(tinggi):
    image_3[x, int(lebar / 2)] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
print('\n')

image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# Menyilang garis pada titik tengah
for x in range(tinggi):
    image_3[x, x] = [255, 255, 255]
for x in range(lebar):
    image_3[x, lebar - x - 1] = [255, 255, 255]


final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=448x224>
# <PIL.Image.Image image mode=RGB size=448x224>

# %%
# Mengubah gambar menjadi RGB
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# Membuat kotak putih
for y in range(70, 150):
    for x in range(70, 150):
        image_3[y, x] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=448x224>

# %%
path_file = ['KTMKu.jpeg']  # Isi dengan nama file gambar lokal Anda

# Baca dan tampilkan image
# for file_name in path_file:
#     # Mendapatkan path lengkap dari file
#     full_path = os.path.join(os.getcwd(), file_name)

#     # Membaca gambar dari file lokal
#     image = cv.imread(full_path)

#     # Mengecek apakah gambar berhasil dibaca
#     if image is None:
#         print(f"Gambar tidak ditemukan atau tidak bisa dibaca: {full_path}")
#         continue

#     # Resize image to half size
#     image = cv.resize(image, (0, 0), fx=0.5, fy=0.5)

#     # Convert color to RGB
#     image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#     # Concatenate original and RGB image
#     final_frame = cv.hconcat([image, image_2])
for file_name in path_file:
    image = io.imread(url)                           # read image
    image = cv.resize(image, (0,0), fx=0.5, fy=0.5)  # resize image to half size
    image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)   # convert color to RGB
    final_frame = cv.hconcat([image, image_2])       # concatenate image
    cv2_imshow(final_frame)                          # show image
    print('\n')

    # plt.imshow(final_frame)
    # plt.axis('off')  # Matikan axis untuk tampilan yang lebih bersih
    # plt.subplots_adjust(left=0, right=1, top=1, bottom=0)  # Hilangkan margin
    # plt.show()
    # print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=448x224>

# %%
from skimage import io
import cv2 as cv
from google.colab.patches import cv2_imshow

path_file = ["/content/sample_data/KTMKu.jpeg"]

for file_name in path_file:
    image = io.imread(file_name)                      # read image using the file path
    image = cv.resize(image, (0, 0), fx=0.5, fy=0.5)  # resize image to half size
    image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)    # convert color to RGB
    final_frame = cv.hconcat([image, image_2])        # concatenate images horizontally
    cv2_imshow(final_frame)                           # show image
    print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=1280x400>

# %%
import cv2 as cv
import matplotlib.pyplot as plt

# Path file image
path_file = "/content/sample_data/KTMKu.jpeg"

# Fungsi untuk menutup bagian tengah gambar dengan dua warna berbeda
def cover_center(image, areas_colors):
    covered_image = image.copy()
    for (top_left, bottom_right, color) in areas_colors:
        covered_image[top_left[1]:bottom_right[1], top_left[0]:bottom_right[0]] = color
    return covered_image

# Membaca image menggunakan OpenCV
image = cv.imread(path_file)

# Resize image ke ukuran setengah
image = cv.resize(image, (0, 0), fx=0.5, fy=0.5)

# Menutup bagian tengah dengan dua warna tertentu
areas_colors = [
    ((25,25), (110, 110), [0, 255, 255]),
    ((115, 50), (265, 108), [255, 0, 0]),
    ((10, 225), (125, 400), [255, 255,0]),
    ((140, 340), (250, 370), [0, 255, 255]),  # Area kuning
    ((140, 310), (420, 340), [0, 0, 0]),      # Area hitam
    ((140, 370), (300, 400), [255, 0, 0]),
    ((330, 245), (437, 275), [0, 0, 0])
]

image_with_center_covered = cover_center(image, areas_colors)

# Konversi warna dari BGR ke RGB untuk Matplotlib
image_rgb = cv.cvtColor(image_with_center_covered, cv.COLOR_BGR2RGB)

# Menampilkan gambar yang telah dimodifikasi menggunakan Matplotlib (RGB format)
plt.xticks(ticks=range(0, image_rgb.shape[1], 25), fontsize=8)
plt.yticks(ticks=range(0, image_rgb.shape[0], 25), fontsize=8)
plt.imshow(image_rgb)
plt.axis('on')
plt.show()

# %%
import cv2 as cv
import matplotlib.pyplot as plt

# Path file image
path_file = "/content/sample_data/KTMKu.jpeg"

# Fungsi untuk menutup bagian tengah gambar dengan dua warna berbeda
def cover_center(image, areas_colors):
    covered_image = image.copy()
    for (top_left, bottom_right, color) in areas_colors:
        covered_image[top_left[1]:bottom_right[1], top_left[0]:bottom_right[0]] = color
    return covered_image

# Membaca image menggunakan OpenCV
image = cv.imread(path_file)

# Resize image ke ukuran setengah
image = cv.resize(image, (0, 0), fx=0.5, fy=0.5)

# Menutup bagian tengah dengan dua warna tertentu
areas_colors = [
    ((140, 340), (250, 370), [0, 255, 255]),  # Area kuning
    ((10, 230), (130, 390), [0, 0, 0])       # Area hitam
]

image_with_center_covered = cover_center(image, areas_colors)

# Konversi warna dari BGR ke RGB untuk Matplotlib
image_rgb = cv.cvtColor(image_with_center_covered, cv.COLOR_BGR2RGB)

# Menampilkan gambar yang telah dimodifikasi menggunakan Matplotlib (RGB format)
plt.xticks(ticks=range(0, image_rgb.shape[1], 25), fontsize=8)
plt.yticks(ticks=range(0, image_rgb.shape[0], 25), fontsize=8)
plt.imshow(image_rgb)
plt.axis('on')
plt.show()

# %%
import cv2 as cv
import matplotlib.pyplot as plt

# Path file image
path_file = "/content/sample_data/KTMKu.jpeg"

# Fungsi untuk menutup bagian tengah gambar dengan dua warna berbeda
def cover_center(image, areas_colors):
    covered_image = image.copy()
    for (top_left, bottom_right, color) in areas_colors:
        covered_image[top_left[1]:bottom_right[1], top_left[0]:bottom_right[0]] = color
    return covered_image

# Membaca image menggunakan OpenCV
image = cv.imread(path_file)

# Resize image ke ukuran setengah
image = cv.resize(image, (0, 0), fx=0.5, fy=0.5)

# Menutup bagian tengah dengan dua warna tertentu
areas_colors = [
    ((140, 340), (250, 370), [0, 255, 255]),  # Area kuning
    ((10, 230), (130, 390), [0, 0, 0])       # Area hitam
]

image_with_center_covered = cover_center(image, areas_colors)

# Konversi warna dari BGR ke RGB untuk Matplotlib
image_rgb = cv.cvtColor(image_with_center_covered, cv.COLOR_BGR2RGB)

# Menampilkan gambar yang telah dimodifikasi menggunakan Matplotlib (RGB format)
plt.xticks(ticks=range(0, image_rgb.shape[1], 25), fontsize=8)
plt.yticks(ticks=range(0, image_rgb.shape[0], 25), fontsize=8)
plt.imshow(image_rgb)
plt.axis('on')
plt.show()
